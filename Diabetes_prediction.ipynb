# %% [markdown]
# # Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe (also known as the Pima Indians). In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima Indian heritage.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima tribe by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function which scores likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome : Class variable (0: person is not diabetic or 1: person is diabetic)

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
pima = pd.read_csv("diabetes.csv")
pima.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 995            2      173             79             32      474  35.504233
# 996           13      132             70             30      111  35.271769
# 997            3      132             87             44      156  34.794755
# 998            0      140              0              0        0  41.926693
# 999            4       93             59             35       93  45.914499
#
#      DiabetesPedigreeFunction  Age  Outcome
# 995                  0.402867   21        1
# 996                  0.168845   42        1
# 997                  0.765003   29        1
# 998                  0.209833   28        1
# 999                  0.737636   29        1

# %%
pima.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
pima.ndim
# Out:
# 2

# %%
pima.size
# Out:
# 9000

# %%
pima.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
#Finding missing values in the dataset
pima.isnull().values.any()
# Out:
# False

# %%
#finding the summary statistics for all variables except for  'Outcome' variable

pima.iloc[:,:pima.columns.get_loc('Outcome')].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1000.000000  1000.00000    1000.000000    1000.000000  1000.000000
# mean      4.051000   125.21600      69.072000      20.755000    83.086000
# std       3.325576    32.27772      20.465328      16.008599   117.255326
# min       0.000000     0.00000       0.000000       0.000000     0.000000
# 25%       1.000000   102.00000      64.000000       0.000000     0.000000
# 50%       3.000000   122.00000      72.000000      24.000000    23.000000
# 75%       6.000000   146.00000      80.000000      33.000000   133.500000
# max      17.000000   199.00000     122.000000      99.000000   846.000000
#
#                BMI  DiabetesPedigreeFunction          Age
# count  1000.000000               1000.000000  1000.000000
# mean     32.664772                  0.494090    33.830000
# std       7.563614                  0.322158    11.268189
# min       0.000000                  0.078000    21.000000
# ...

# %%
#distribution plot for the variable BloodPressure
sns.displot(pima['BloodPressure'], kind='kde')
plt.show()

# %% [markdown]
# #### Observation from the distribution plot:

# %% [raw]
# Majority of the people in dataframe has blood pressure in the range of 50-100 mm/hg, where the highest is around 75 mm/hg

# %% [markdown]
# #### Finding the `'BMI'` for the person having the highest `'Glucose'`

# %%
pima[pima['Glucose']==pima['Glucose'].max()]['BMI']
# Out:
# 661    42.9
# Name: BMI, dtype: float64

# %% [markdown]
# ### Finding Statistical data of BMI

# %%
#remove _____ & write the appropriate function name

m1 = pima['BMI'].mean()  #Mean
print(m1)
m2 = pima['BMI'].median()  #Median
print(m2)
m3 = pima['BMI'].mode()[0]  #Mode
print(m3)
# Out:
# 32.664772391408796
# 32.8
# 32.0

# %% [markdown]
# ### Finding how many women's `'Glucose'` level is above the mean level of `'Glucose'`.

# %%
pima[pima['Glucose']>pima['Glucose'].mean()].shape[0]
# Out:
# 449

# %% [markdown]
# #### Observation :

# %% [raw]
# 449 of women have glucose level more than the mean

# %% [markdown]
# ### Creating the pairplot for variables `'Glucose'`, `'SkinThickness'` and `'DiabetesPedigreeFunction'`.

# %%
sns.pairplot(data=pima, vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()

# %% [markdown]
# #### Observation:

# %% [raw]
# The given chart represents the relationship between Glucose, SkinThickness and DiabetesPedigreeFunction. With some of the outliers, glucose and diabetespredigree function are skewed negatively.

# %% [markdown]
# ### Ploting the scatterplot between `'Glucose'` and `'Insulin'`.

# %%
sns.scatterplot(x='Glucose',y='Insulin',data=pima)
plt.show()

# %% [markdown]
# #### Observation:

# %% [raw]
# From the above graph we can see that there is a linear relationship between insuline and glucose.

# %% [markdown]
# ### Ploting the boxplot for the 'Age' variable for finding the outliers.

# %%
plt.boxplot(pima['Age'])
plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Observation:

# %% [raw]
# yes there are many outliers represented by the box plot.

# %% [markdown]
# ###  Finding and visualizing the the correlation matrix.

# %%
corr_matrix = pima.iloc[:,0:8].corr()
corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.112930       0.127463      -0.080033
# Glucose                      0.112930  1.000000       0.134993       0.050656
# BloodPressure                0.127463  0.134993       1.000000       0.249063
# SkinThickness               -0.080033  0.050656       0.249063       1.000000
# Insulin                     -0.064909  0.334175       0.117369       0.472663
# BMI                          0.012920  0.222138       0.247275       0.387055
# DiabetesPedigreeFunction    -0.025452  0.127004       0.059303       0.214026
# Age                          0.548665  0.255567       0.240416      -0.121236
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.064909  0.012920                 -0.025452
# Glucose                   0.334175  0.222138                  0.127004
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot = True)
# display the plot
plt.show()

# %% [markdown]
# #### Observation:

# %% [raw]
# Heat map shows the correlation between two variable on the axis. red means they are corelated with each other and black color means they are not much corelated to each other.
# from the heatmap we can see that in red color, the age and pregnancies have a good relationship at 0.55.

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Spliting and scaling the data.

# %%
# Splited the data into dependent and independent variables
y = pima.Outcome
x = pima.drop('Outcome', axis = 1)

# %%
# Using StandarScaler to scale the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(x)

# %%
# Splitting the data into train and test.Using test size as 15%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15, stratify=y,  random_state = 45)

# %% [markdown]
# ###  Training a Logistic Regression Model and finding it's Accuracy.

# %%
# remove _____ & complete the code

# import the model
from sklearn.linear_model import LogisticRegression

# Instantiate the model
lr = LogisticRegression(solver='lbfgs', max_iter=150)

# fit the model on the train set
m = lr.fit(x_train, y_train)

# Predict on x_test
y_pred = m.predict(x_test)

# Evaluate the model
print('Accuracy of Logistic Regression model on the train set: {:.2f}'.format(m.score(x_train, y_train)))
print('Accuracy of the Logictic Regression model on the test set: {:.2f}'.format(m.score(x_test, y_test)))

from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy of Logistic Regression model on the train set: 0.76
# Accuracy of the Logictic Regression model on the test set: 0.75
# array([[60, 15],
#        [22, 53]])

# %% [markdown]
# #### Observation

# %% [markdown]
# Accuracy of the test set is 0.75 and on train set is 0.76, in which, we got 60 true positive and 53 true negatives.

# %% [markdown]
# ###  Training a Random Forest Model and finding it's Accuracy.

# %%
#remove _____ & complete the code

# Import the Model
from sklearn.ensemble import RandomForestClassifier

# Instantiate the model. 
rf = RandomForestClassifier(n_estimators=301, max_depth=3)

# fit the model on the train set
m2 = rf.fit(x_train, y_train)

# Predict on x_test
y_pred2 = m2.predict(x_test)

# Evaluate the Model
print('Accuracy of Random Forest model on the train set: {:.2f}'.format(m2.score(x_train, y_train)))
print('Accuracy of Random Forest model on the test set: {:.2f}'.format(m2.score(x_test, y_test)))
confusion_matrix(y_test, y_pred2)
# Out:
# Accuracy of Random Forest model on the train set: 0.82
# Accuracy of Random Forest model on the test set: 0.78
# array([[56, 19],
#        [14, 61]])

# %% [markdown]
# #### Observation:

# %% [markdown]
# Accuracy of the train set is 0.82 and accuracy on test set is 0.79. here we have 56 true positives and 62 true negatives.

# %% [markdown]
# ### Comparing the Logistic Regression and Random Forest Model result and accuracy.

# %% [raw]
# By considering the accuracy of both the model we can say that random forest perform better and is more accurate in this case than Logistic Regression Model.
